# %%
import os
import cv2
import time
import numpy as np
import shutil
from FaceDetectionModule import Face_Detector
from FaceLandmarksModule import Landmark_Extractor
import imutils
from imutils import face_utils
import dlib
import matplotlib.pyplot as plt
from scipy.dis
# Out:
# Imported Python modules.

# %%
def euclidean_dist(ptA, ptB):
 # compute and return the euclidean distance between the two
 # points
    return np.linalg.norm(ptA - ptB)

# %%
device = "CPU"
cpu_extension_path = "cpu_extension_avx2.dll"
detection_thresh = 0.7
landmarks_file = "Models/shape_predictor_68_face_landmarks.dat"

# %%
model_xml = r"Models/openvino/face-detection/FP16/face-detection-retail-0004.xml"
model_bin = r"Models/openvino/face-detection/FP16/face-detection-retail-0004.bin"

plugin = Face_Detector.init_plugin(device,cpu_extension_path)

faceDetector = Face_Detector()

faceDetector.load_net(model_xml,model_bin,plugin)
# Out:
# INFO: All network layers are supported.
# Input Shape: [1, 3, 300, 300]
# Output Shape: [1, 1, 200, 7]

# %%
model_xml = r"Models/openvino/face-landmarks/FP16/facial-landmarks-35-adas-0002.xml"
model_bin = r"Models/openvino/face-landmarks/FP16/facial-landmarks-35-adas-0002.bin"

landmarkExtractor = Landmark_Extractor()

landmarkExtractor.load_net(model_xml,model_bin,plugin)
# Out:
# INFO: All network layers are supported.
# Input Shape: [1, 3, 60, 60]
# Output Shape: [1, 70]

# %%
predictor = dlib.shape_predictor(landmarks_file)

# %%
img = cv2.imread(r"C:\Users\ADNEC- VW 3\Notebooks\IMG_TEST\Osama.jpg")
img_orig = img.copy()
faces = faceDetector.detectFaces(img)[0]
for (x_min,y_min,x_max,y_max) in faces:
    cv2.rectangle(img,(x_min,y_min),(x_max,y_max),(255,255,0),2)
    #img = img[y_min:y_max,x_min:x_max]  
cv2.imshow("output",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

img = img[y_min:y_max,x_min:x_max]
(x_min,y_min,x_max,y_max) = (0,0,img.shape[1],img.shape[0])
img = landmarkExtractor.prepare_face(img)

cv2.imshow("output",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
shape = predictor(img, dlib.rectangle(x_min,y_min,x_max,y_max))

r_eye_points= list(map(lambda p:(p.x,p.y), list(shape.parts()[42:48])))
l_eye_points = list(map(lambda p:(p.x,p.y), list(shape.parts()[36:42])))
print(r_eye_points) 
for p in r_eye_points:
    cv2.circle(img,p,2,(255,255,0),-1)
    
for p in l_eye_points:
    cv2.circle(img,p,2,(255,255,0),-1)

cv2.imshow("output",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [(117, 146), (129, 137), (141, 138), (151, 146), (141, 151), (129, 150)]

# %%
def extract_landmarks(img,return_img = False):
    faces = faceDetector.detectFaces(img)
    if faces is None or len(faces) == 0:
        return [],[]
    (x_min,y_min,x_max,y_max)= faces[0][0]
    
    img_crop = img[y_min:y_max,x_min:x_max]
    (x_min,y_min,x_max,y_max) = (0,0,img_crop.shape[1],img_crop.shape[0])
    img_crop = landmarkExtractor.prepare_face(img_crop)
    
    #img = img[y_min:y_max,x_min:x_max]  
    #img = imutils.resize(img,height = 300)
    #img = landmarkExtractor.prepare_face(img)
   # landmarks = landmarkExtractor.extractLandmarks(img)
    #landmarks = list(map(lambda x:(int(x[0]*img.shape[1]),int(x[1]*img.shape[0])),landmarks))
    #left_eye_landmarks = [landmarks[0],landmarks[1],landmarks[12],landmarks[14]]
    #right_eye_landmarks = [landmarks[2],landmarks[3],landmarks[17],landmarks[15]]
    shape = predictor(cv2.cvtColor(img_crop,cv2.COLOR_BGR2GRAY), dlib.rectangle(x_min,y_min,x_max,y_max))
    r_eye_points= list(map(lambda p:(p.x,p.y), list(shape.parts()[42:48])))
    l_eye_points = list(map(lambda p:(p.x,p.y), list(shape.parts()[36:42])))
    if return_img:
        return r_eye_points,l_eye_points,img_crop
    else:
        return r_eye_points,l_eye_points

# %%
def append(arr1,arr2):
    arr_result = arr1.copy()
    for element in arr2:
        arr_result.append(element)
    return arr_result

# %%
def eye_aspect_ratio(eye):
# compute the euclidean distances between the two sets of
 # vertical eye landmarks (x, y)-coordinates
    a = euclidean_dist(eye[1], eye[5])
    b = euclidean_dist(eye[2], eye[4])

 # compute the euclidean distance between the horizontal
 # eye landmark (x, y)-coordinates
    c = euclidean_dist(eye[0], eye[3])

 # compute the eye aspect ratio
    ear = (a + b) / (2.0 * c)

 # return the eye aspect ratio
    return ear

# %%
cap = cv2.VideoCapture(0)
cap_w = 1920
cap_h = 1080
cap.set(cv2.CAP_PROP_FRAME_WIDTH,cap_w)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,cap_h)
# Out:
# True

# %%
cap.release()

# %%
ret,img_orig =  cap.read()

plt.imshow(img_orig)

both_eyes_closed(img_orig)

# %%
#img_orig = cv2.imread(r"C:\Users\ADNEC- VW 3\Notebooks\IMG_TEST\closed2.jpg")
ret,img_orig =  cap.read()
img = img_orig.copy()

right_eye_landmarks,left_eye_landmarks,img = extract_landmarks(img,True)

right_eye_cnts = []
for lm in right_eye_landmarks:
    right_eye_cnts.append(list(lm))
right_eye_cnts = np.array(right_eye_cnts,dtype="int32")

left_eye_cnts = []
for rm in left_eye_landmarks:
    left_eye_cnts.append(list(rm))
left_eye_cnts = np.array(left_eye_cnts,dtype="int32")


r_ear = eye_aspect_ratio(right_eye_cnts)
l_ear = eye_aspect_ratio(left_eye_cnts)

hull_r = cv2.convexHull(right_eye_cnts)
hull_l = cv2.convexHull(left_eye_cnts)
(x1,y1,w1,h1) = cv2.boundingRect(hull_r)
(x2,y2,w2,h2)  = cv2.boundingRect(hull_l)

cnt_r_area = w1*h1
cnt_l_area = w2*h2
hull_r_area = cv2.contourArea(hull_r)
hull_l_area = cv2.contourArea(hull_l)
solidity_r = cnt_r_area/hull_r_area
solidity_l = cnt_l_area/hull_l_area
r_ratio = w1/h1
l_ratio = w2/h2

print(solidity_r)
print(solidity_l)
print("Right Aspect Ratio: {}".format(r_ratio))
print("Left Aspect Ratio: {}".format(l_ratio))

temp = img.copy()

cv2.rectangle(temp,(x1,y1),(x1+w1,y1+h1),(0,255,0),2)
cv2.rectangle(temp,(x2,y2),(x2+w2,y2+h2),(0,255,0),2)

temp = cv2.drawContours(temp,[hull_r,hull_l],-1,(255,255,0),3)
cv2.imshow("output",temp)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0.32301900711705694
# 1.574456948442816
# 1.690909090909091
# Right Aspect Ratio: 2.9375
# Left Aspect Ratio: 2.5833333333333335

# %%
hull_l
# Out:
# array([[[122, 229]],
#
#        [[102, 238]],
#
#        [[ 80, 240]],
#
#        [[ 63, 235]],
#
#        [[ 80, 220]],
#
#        [[102, 217]]], dtype=int32)

# %%
def both_eyes_closed(img):
    
    try:
        right_eye_landmarks,left_eye_landmarks = extract_landmarks(img)
    except:
        return None
    
    if right_eye_landmarks == []:
        return None
  #  print(right_eye_landmarks[1][1] - right_eye_landmarks[5][1])
    right_eye_cnts = []
    for lm in right_eye_landmarks:
        right_eye_cnts.append(list(lm))
    right_eye_cnts = np.array(right_eye_cnts,dtype="int32")

    left_eye_cnts = []
    for rm in left_eye_landmarks:
        left_eye_cnts.append(list(rm))
    left_eye_cnts = np.array(left_eye_cnts,dtype="int32")

    hull_r = cv2.convexHull(right_eye_cnts)
    hull_l = cv2.convexHull(left_eye_cnts)
    (x1,y1,w1,h1) = cv2.boundingRect(hull_r)
    (x2,y2,w2,h2)  = cv2.boundingRect(hull_l)

    cnt_r_area = w1*h1
    cnt_l_area = w2*h2
    hull_r_area = cv2.contourArea(hull_r)
    hull_l_area = cv2.contourArea(hull_l)
    solidity_r = cnt_r_area/hull_r_area
    solidity_l = cnt_l_area/hull_l_area
    r_ratio = w1/h1
    l_ratio = w2/h2
    
    
    print(solidity_r)
    print(solidity_l)
    print("Right Aspect Ratio: {}".format(r_ratio))
    print("Left Aspect Ratio: {}".format(l_ratio))
    
    if solidity_r>2.3 and solidity_l>2.3:
        return True
    
    if r_ratio>4 and l_ratio>4:
        return True
    return False

# %% [markdown]
# import glob
# import matplotlib.pyplot as plt
# for img_path in glob.glob("/home/pi/Notebooks/FaceRecognitionFramework/Images_/query/*.*"):
#     img = cv2.imread(img_path)
#     if img is None:
#         continue
#     closed = both_eyes_closed(img)
#     cv2.imshow(str(closed),img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)
cap_w = 800
cap_h = 600
cap.set(cv2.CAP_PROP_FRAME_WIDTH,cap_w)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,cap_h)
drowsiness_alert_frames = 10
drowsiness_count =0

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    if ret == False:
        continue
    
    closed = both_eyes_closed(frame)
    if closed == True:
        #print("closed")
        drowsiness_count = min(drowsiness_alert_frames + (drowsiness_alert_frames*0.5),
                            drowsiness_count+1)
        cv2.putText(frame,"Eyes Closed",(100,100),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,0),1)
    elif closed == False:
        drowsiness_count = max(0,drowsiness_count-1)
        cv2.putText(frame,"Eyes Open",(100,100),cv2.FONT_HERSHEY_SIMPLEX,2,(255,255,0),1)
    #print(drowsiness_count)   
    if drowsiness_count>=drowsiness_alert_frames:
        print("Alert")
    cv2.imshow('frame',frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cap.release()
cv2.destroyAllWindows()
# Out:
# 1.5834767641996557
# 1.6923076923076923
# Right Aspect Ratio: 2.3
# Left Aspect Ratio: 2.0454545454545454
# 1.657387580299786
# 1.812807881773399
# Right Aspect Ratio: 2.388888888888889
# Left Aspect Ratio: 2.3
# 1.5720430107526882
# 1.718279569892473
# Right Aspect Ratio: 2.5294117647058822
# Left Aspect Ratio: 2.764705882352941
# 1.7524339360222532
# 1.6336499321573947
# Right Aspect Ratio: 2.8
# Left Aspect Ratio: 3.0714285714285716
# 1.76231884057971
# 1.6774193548387097
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.7857142857142856
# 1.661807580174927
# 1.6677115987460815
# Right Aspect Ratio: 2.533333333333333
# Left Aspect Ratio: 2.7142857142857144
# 1.6286107290233838
# 1.7381615598885793
# Right Aspect Ratio: 2.3125
# Left Aspect Ratio: 2.4375
# 1.7845303867403315
# 1.625
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.7857142857142856
# 1.669242658423493
# 1.7076923076923076
# Right Aspect Ratio: 2.4
# Left Aspect Ratio: 2.466666666666667
# 1.6742081447963801
# 1.7298937784522004
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.533333333333333
# 1.7636887608069165
# 1.674931129476584
# Right Aspect Ratio: 2.1176470588235294
# Left Aspect Ratio: 2.375
# 1.6551724137931034
# 1.6180758017492711
# Right Aspect Ratio: 2.25
# Left Aspect Ratio: 2.466666666666667
# 1.6551724137931034
# 1.7030812324929971
# Right Aspect Ratio: 2.25
# Left Aspect Ratio: 2.375
# 1.6666666666666667
# 1.6772046589018303
# Right Aspect Ratio: 2.4
# Left Aspect Ratio: 2.5714285714285716
# 1.7182662538699691
# 1.6996805111821087
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.7142857142857144
# 1.6818181818181819
# 1.6795580110497237
# Right Aspect Ratio: 2.176470588235294
# Left Aspect Ratio: 2.375
# 1.7044854881266491
# 1.645466847090663
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.375
# 1.6699576868829338
# 1.7259475218658893
# Right Aspect Ratio: 2.3125
# Left Aspect Ratio: 2.3125
# 1.643835616438356
# 1.7307692307692308
# Right Aspect Ratio: 2.4
# Left Aspect Ratio: 2.4
# 1.6567164179104477
# 1.6420118343195267
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.466666666666667
# 1.6955810147299508
# 1.6955810147299508
# Right Aspect Ratio: 2.642857142857143
# Left Aspect Ratio: 2.642857142857143
# 1.710267229254571
# 1.7076923076923076
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.466666666666667
# 1.6897001303780965
# 1.6108843537414965
# Right Aspect Ratio: 2.0
# Left Aspect Ratio: 2.3125
# 1.8090452261306533
# 1.7087033747779752
# Right Aspect Ratio: 2.4
# Left Aspect Ratio: 2.8461538461538463
# 1.7284671532846716
# 1.7259475218658893
# Right Aspect Ratio: 2.3125
# Left Aspect Ratio: 2.3125
# 1.6153846153846154
# 1.682804674457429
# Right Aspect Ratio: 2.5714285714285716
# Left Aspect Ratio: 2.5714285714285716
# 1.677762982689747
# 1.7
# Right Aspect Ratio: 1.9444444444444444
# Left Aspect Ratio: 2.176470588235294
# 1.825657894736842
# 1.7733333333333334
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.7142857142857144
# 1.6709677419354838
# 1.736462093862816
# Right Aspect Ratio: 2.642857142857143
# Left Aspect Ratio: 2.8461538461538463
# 1.693848354792561
# 1.7259475218658893
# Right Aspect Ratio: 2.3125
# Left Aspect Ratio: 2.3125
# 1.6108843537414965
# 1.6795580110497237
# Right Aspect Ratio: 2.3125
# Left Aspect Ratio: 2.375
# 1.6468842729970326
# 1.7076923076923076
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.466666666666667
# 1.6946826758147513
# 1.7338403041825095
# Right Aspect Ratio: 2.923076923076923
# Left Aspect Ratio: 3.1666666666666665
# 1.775182481751825
# 1.6825885978428352
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.7857142857142856
# 1.6353591160220995
# 1.7566765578635015
# Right Aspect Ratio: 2.3125
# Left Aspect Ratio: 2.3125
# 1.6170212765957446
# 1.6764705882352942
# Right Aspect Ratio: 2.111111111111111
# Left Aspect Ratio: 2.111111111111111
# 1.6593886462882097
# 1.7076923076923076
# Right Aspect Ratio: 2.533333333333333
# Left Aspect Ratio: 2.466666666666667
# 1.8
# 1.8269230769230769
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.533333333333333
# 1.6432432432432433
# 1.7030812324929971
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.375
# 1.6354430379746836
# 1.7030812324929971
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.375
# 1.7156105100463679
# 1.7648766328011611
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.375
# 1.786833855799373
# 1.7645107794361525
# Right Aspect Ratio: 2.533333333333333
# Left Aspect Ratio: 2.7142857142857144
# 1.8606403013182675
# 1.7737881508078994
# Right Aspect Ratio: 2.923076923076923
# Left Aspect Ratio: 2.923076923076923
# 1.693315858453473
# 1.6888888888888889
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.235294117647059
# 1.8445945945945945
# 1.7963636363636364
# Right Aspect Ratio: 2.7857142857142856
# Left Aspect Ratio: 2.923076923076923
# 1.6451612903225807
# 1.6790123456790123
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.3529411764705883
# 1.7021822849807446
# 1.7106918238993711
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.3529411764705883
# 1.7044854881266491
# 1.7142857142857142
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.4375
# 1.677241379310345
# 1.6888888888888889
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.235294117647059
# 1.641677255400254
# 1.657370517928287
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.4375
# 1.750788643533123
# 1.6703296703296704
# Right Aspect Ratio: 2.466666666666667
# Left Aspect Ratio: 2.7142857142857144
# 1.6794258373205742
# 1.7440993788819876
# Right Aspect Ratio: 2.1666666666666665
# Left Aspect Ratio: 2.1666666666666665
# 1.6551724137931034
# 1.725067385444744
# Right Aspect Ratio: 2.4375
# Left Aspect Ratio: 2.5
# 1.7292882147024504
# 1.6875
# Right Aspect Ratio: 2.0526315789473686
# Left Aspect Ratio: 2.1666666666666665
# 1.7043701799485862
# 1.7209876543209877
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.411764705882353
# 1.9720558882235528
# 1.8352941176470587
# Right Aspect Ratio: 2.923076923076923
# Left Aspect Ratio: 3.25
# 1.6825885978428352
# 1.8230383973288815
# Right Aspect Ratio: 2.7857142857142856
# Left Aspect Ratio: 2.7857142857142856
# 1.645466847090663
# 1.7142857142857142
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.4375
# 1.7043941411451398
# 1.7112299465240641
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.5
# 1.569811320754717
# 1.6790123456790123
# Right Aspect Ratio: 2.4375
# Left Aspect Ratio: 2.3529411764705883
# 1.626882966396292
# 1.6921269095182139
# Right Aspect Ratio: 2.1666666666666665
# Left Aspect Ratio: 2.2222222222222223
# 1.5710900473933649
# 1.615650172612198
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.1666666666666665
# 1.6575790621592148
# 1.6556603773584906
# Right Aspect Ratio: 2.1052631578947367
# Left Aspect Ratio: 2.1666666666666665
# 1.691566265060241
# 1.6210268948655258
# Right Aspect Ratio: 2.1666666666666665
# Left Aspect Ratio: 2.2941176470588234
# 1.6576151121605667
# 1.6744186046511629
# Right Aspect Ratio: 2.1666666666666665
# Left Aspect Ratio: 2.2222222222222223
# 1.6170212765957446
# 1.7
# Right Aspect Ratio: 2.111111111111111
# Left Aspect Ratio: 2.2941176470588234
# 1.68944099378882
# 1.6558861578266495
# Right Aspect Ratio: 2.3529411764705883
# Left Aspect Ratio: 2.5
# 1.683168316831683
# 1.691326530612245
# Right Aspect Ratio: 2.3529411764705883
# Left Aspect Ratio: 2.2941176470588234
# 1.612983770287141
# 1.6981132075471699
# Right Aspect Ratio: 2.235294117647059
# Left Aspect Ratio: 2.2222222222222223
# 1.7256637168141593
# 1.7366136034732271
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.6666666666666665
# 1.7493403693931397
# 1.7142857142857142
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.4375
# 1.8083462132921175
# 1.7307692307692308
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.6
# 1.691566265060241
# 1.6666666666666667
# Right Aspect Ratio: 2.1666666666666665
# Left Aspect Ratio: 2.2222222222222223
# 1.6472049689440993
# 1.7349397590361446
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.2222222222222223
# 1.7359050445103859
# 1.802773497688752
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.6
# 1.7021822849807446
# 1.6368286445012787
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.5
# 1.6451612903225807
# 1.669250645994832
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.235294117647059
# 1.6161616161616161
# 1.6267942583732058
# Right Aspect Ratio: 2.2222222222222223
# Left Aspect Ratio: 2.3529411764705883
# 1.6131386861313868
# 1.6267942583732058
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.3529411764705883
# 1.7002724795640327
# 1.725067385444744
# Right Aspect Ratio: 2.4375
# Left Aspect Ratio: 2.5
# 1.713520749665328
# 1.7142857142857142
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.4375
# 1.645466847090663
# 1.6838995568685378
# Right Aspect Ratio: 2.375
# Left Aspect Ratio: 2.533333333333333
# 1.8641509433962264
# 1.7404580152671756
# Right Aspect Ratio: 2.923076923076923
# Left Aspect Ratio: 3.1666666666666665
# 1.7413572343149808
# 1.741654571843251
# Right Aspect Ratio: 2.3529411764705883
# Left Aspect Ratio: 2.6666666666666665
# 1.8481848184818481
# 1.6984924623115578
# Right Aspect Ratio: 2.857142857142857
# Left Aspect Ratio: 3.0
# 1.691326530612245
# 1.693121693121693
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.5
# 1.66883963494133
# 1.7066666666666668
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.5
# 1.6690442225392297
# 1.7231222385861562
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.6
# 1.6842105263157894
# 1.773142112125163
# Right Aspect Ratio: 2.4375
# Left Aspect Ratio: 2.3529411764705883
# 1.9293286219081272
# 1.7727272727272727
# Right Aspect Ratio: 2.7857142857142856
# Left Aspect Ratio: 3.0
# 1.7213793103448276
# 1.7307692307692308
# Right Aspect Ratio: 2.4375
# Left Aspect Ratio: 2.6
# 1.7391304347826086
# 1.725067385444744
# Right Aspect Ratio: 2.3529411764705883
# Left Aspect Ratio: 2.5
# 1.6347381864623245
# 1.6790123456790123
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.3529411764705883
# 1.7142857142857142
# 1.741654571843251
# Right Aspect Ratio: 2.6666666666666665
# Left Aspect Ratio: 2.6666666666666665
# 1.8046767537826685
# 1.725067385444744
# Right Aspect Ratio: 2.5625
# Left Aspect Ratio: 2.5
# 1.797752808988764
# 1.721664275466284
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.6666666666666665
# 1.8083462132921175
# 1.7307692307692308
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.6
# 1.6350184956843403
# 1.7142857142857142
# Right Aspect Ratio: 2.2941176470588234
# Left Aspect Ratio: 2.4375
# 1.7679558011049723
# 1.7307692307692308
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.6
# 1.683168316831683
# 1.7121951219512195
# Right Aspect Ratio: 2.3529411764705883
# Left Aspect Ratio: 2.1666666666666665
# 1.657370517928287
# 1.728813559322034
# Right Aspect Ratio: 2.4375
# Left Aspect Ratio: 2.2941176470588234
# 1.6805896805896805
# 1.6326530612244898
# Right Aspect Ratio: 2.111111111111111
# Left Aspect Ratio: 2.3529411764705883
# 1.6344586728754364
# 1.6763678696158324
# Right Aspect Ratio: 2.1666666666666665
# Left Aspect Ratio: 2.2222222222222223
# 1.6056338028169015
# 1.6795580110497237
# Right Aspect Ratio: 2.0526315789473686
# Left Aspect Ratio: 2.1052631578947367
# 1.565217391304348
# 1.691275167785235
# Right Aspect Ratio: 2.2222222222222223
# Left Aspect Ratio: 2.3333333333333335
# 1.5720524017467248
# 1.7540106951871657
# Right Aspect Ratio: 2.2222222222222223
# Left Aspect Ratio: 2.05
# 1.598477640342531
# 1.6573208722741433
# Right Aspect Ratio: 2.1
# Left Aspect Ratio: 2.210526315789474
# 1.8353658536585367
# 1.8909090909090909
# Right Aspect Ratio: 3.0714285714285716
# Left Aspect Ratio: 3.3846153846153846
# 1.7311475409836066
# 1.6779661016949152
# Right Aspect Ratio: 2.4444444444444446
# Left Aspect Ratio: 2.4444444444444446
# 1.596311475409836
# 1.6669990029910269
# Right Aspect Ratio: 2.1578947368421053
# Left Aspect Ratio: 2.3157894736842106
# 1.762672811059908
# 1.765237020316027
# Right Aspect Ratio: 2.6470588235294117
# Left Aspect Ratio: 2.7058823529411766
# 1.767231638418079
# 1.7712344280860701
# Right Aspect Ratio: 2.7058823529411766
# Left Aspect Ratio: 2.7058823529411766
# 1.8613861386138615
# 1.821705426356589
# Right Aspect Ratio: 2.9375
# Left Aspect Ratio: 3.1333333333333333
# 1.6613953488372093
# 1.6594641313742438
# Right Aspect Ratio: 2.473684210526316
# Left Aspect Ratio: 2.4
# 1.6791546589817483
# 1.7289812067260137
# Right Aspect Ratio: 2.4210526315789473
# Left Aspect Ratio: 2.4210526315789473
# 1.796875
# 1.7504655493482308
# Right Aspect Ratio: 2.3
# Left Aspect Ratio: 2.35
# 1.7044424297370806
# 1.6651904340124004
# Right Aspect Ratio: 2.35
# Left Aspect Ratio: 2.35
# 1.6981132075471699
# 1.5957446808510638
# Right Aspect Ratio: 2.142857142857143
# Left Aspect Ratio: 2.25
# 1.718780727630285
# 1.6707202993451824
# Right Aspect Ratio: 2.4210526315789473
# Left Aspect Ratio: 2.473684210526316
# 1.5557476231633536
# 1.6246913580246913
# Right Aspect Ratio: 2.25
# Left Aspect Ratio: 2.238095238095238
# 1.6232339089481946
# 1.5911439114391144
# Right Aspect Ratio: 2.1363636363636362
# Left Aspect Ratio: 2.227272727272727
# 1.6502242152466369
# 1.6578947368421053
# Right Aspect Ratio: 2.3
# Left Aspect Ratio: 2.2857142857142856
# 1.710646041856233
# 1.6607773851590106
# Right Aspect Ratio: 2.35
# Left Aspect Ratio: 2.35
# 1.6549295774647887
# 1.6568047337278107
# Right Aspect Ratio: 2.35
# Left Aspect Ratio: 2.45
# 1.6246913580246913
# 1.6323886639676113
# Right Aspect Ratio: 2.238095238095238
# Left Aspect Ratio: 2.2857142857142856
# 1.613733905579399
# 1.6505706760316066
# Right Aspect Ratio: 2.35
# Left Aspect Ratio: 2.35
# 1.6360759493670887
# 1.6246153846153846
# Right Aspect Ratio: 2.1363636363636362
# Left Aspect Ratio: 2.1818181818181817
# 1.6929674099485421
# 1.6041848299912815
# Right Aspect Ratio: 2.238095238095238
# Left Aspect Ratio: 2.3
# 1.678601165695254
# 1.6512215669755688
# Right Aspect Ratio: 2.2857142857142856
# Left Aspect Ratio: 2.45
# 1.6916299559471366
# 1.6581818181818182
# Right Aspect Ratio: 2.4
# Left Aspect Ratio: 2.526315789473684
# 1.6882690730106644
# 1.5629984051036683
# Right Aspect Ratio: 2.3333333333333335
# Left Aspect Ratio: 2.45
# 1.7163504968383017
# 1.7185332011892964
# Right Aspect Ratio: 2.6315789473684212
# Left Aspect Ratio: 3.0
# 1.7120622568093384
# 1.651503469545104
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.4285714285714284
# 1.6596906278434942
# 1.6498316498316499
# Right Aspect Ratio: 2.526315789473684
# Left Aspect Ratio: 2.45
# 1.8231420507996237
# 1.7435897435897436
# Right Aspect Ratio: 2.6842105263157894
# Left Aspect Ratio: 2.8333333333333335
# 1.96
# 1.990990990990991
# Right Aspect Ratio: 3.769230769230769
# Left Aspect Ratio: 3.923076923076923
# 1.860759493670886
# 1.871559633027523
# Right Aspect Ratio: 3.2666666666666666
# Left Aspect Ratio: 3.1875
# 1.893939393939394
# 1.8672768878718535
# Right Aspect Ratio: 3.3333333333333335
# Left Aspect Ratio: 3.1875
# 1.6973058637083993
# 1.6851851851851851
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.4761904761904763
# 1.6708860759493671
# 1.6960711638250556
# Right Aspect Ratio: 2.3181818181818183
# Left Aspect Ratio: 2.3636363636363638
# 1.6749633967789166
# 1.657370517928287
# Right Aspect Ratio: 2.3636363636363638
# Left Aspect Ratio: 2.6
# 1.7741935483870968
# 1.607717041800643
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.5
# 1.786488740617181
# 1.6189710610932475
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.789473684210526
# 1.7182235834609494
# 1.616580310880829
# Right Aspect Ratio: 2.3181818181818183
# Left Aspect Ratio: 2.4761904761904763
# 1.6986518636003172
# 1.644479248238058
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.380952380952381
# 1.7723718505647263
# 1.707112970711297
# Right Aspect Ratio: 2.55
# Left Aspect Ratio: 2.55
# 1.6985845129059118
# 1.6455696202531647
# Right Aspect Ratio: 2.55
# Left Aspect Ratio: 2.6
# 1.7316087308003234
# 1.6693418940609952
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.6
# 1.7947214076246334
# 1.7711950970377937
# Right Aspect Ratio: 2.8333333333333335
# Left Aspect Ratio: 3.0
# 1.7261410788381744
# 1.7417840375586855
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.5238095238095237
# 1.7647058823529411
# 1.7128463476070528
# Right Aspect Ratio: 2.55
# Left Aspect Ratio: 2.55
# 1.7164303586321934
# 1.6528925619834711
# Right Aspect Ratio: 2.3333333333333335
# Left Aspect Ratio: 2.5
# 2.0834724540901504
# 2.0240963855421685
# Right Aspect Ratio: 3.6923076923076925
# Left Aspect Ratio: 4.083333333333333
# 1.6011602610587383
# 1.6739446870451238
# Right Aspect Ratio: 2.0869565217391304
# Left Aspect Ratio: 2.1739130434782608
# 1.5978260869565217
# 1.6819571865443426
# Right Aspect Ratio: 2.3333333333333335
# Left Aspect Ratio: 2.272727272727273
# 1.6431924882629108
# 1.6496465043205029
# Right Aspect Ratio: 2.380952380952381
# Left Aspect Ratio: 2.380952380952381
# 1.5557056043214044
# 1.6142759094028827
# Right Aspect Ratio: 2.0
# Left Aspect Ratio: 2.0416666666666665
# 1.6126482213438735
# 1.649746192893401
# Right Aspect Ratio: 2.125
# Left Aspect Ratio: 2.08
# 1.6176470588235294
# 1.6751638747268756
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.1739130434782608
# 1.6463683052090976
# 1.626086956521739
# Right Aspect Ratio: 2.3181818181818183
# Left Aspect Ratio: 2.3181818181818183
# 1.7639097744360903
# 1.6422535211267606
# Right Aspect Ratio: 2.217391304347826
# Left Aspect Ratio: 2.409090909090909
# 1.6866141732283464
# 1.75
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.4285714285714284
# 1.6266460108443068
# 1.7203007518796993
# Right Aspect Ratio: 2.380952380952381
# Left Aspect Ratio: 2.3636363636363638
# 1.7601380500431407
# 1.6901408450704225
# Right Aspect Ratio: 2.55
# Left Aspect Ratio: 2.55
# 1.756007393715342
# 1.733705772811918
# Right Aspect Ratio: 2.6315789473684212
# Left Aspect Ratio: 2.5789473684210527
# 1.8369668246445499
# 1.7782426778242677
# Right Aspect Ratio: 2.6842105263157894
# Left Aspect Ratio: 2.9411764705882355
# 1.8499486125385407
# 1.7230769230769232
# Right Aspect Ratio: 2.7777777777777777
# Left Aspect Ratio: 3.0625
# 2.01025641025641
# 1.985267034990792
# Right Aspect Ratio: 4.083333333333333
# Left Aspect Ratio: 4.454545454545454
# 1.7418147801683816
# 1.6381514257620453
# Right Aspect Ratio: 2.5789473684210527
# Left Aspect Ratio: 2.8823529411764706
# 1.6603773584905661
# 1.719941348973607
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.217391304347826
# 1.728813559322034
# 1.8299120234604105
# Right Aspect Ratio: 2.8333333333333335
# Left Aspect Ratio: 2.888888888888889
# 1.6354538956397426
# 1.6422535211267606
# Right Aspect Ratio: 2.3636363636363638
# Left Aspect Ratio: 2.409090909090909
# 1.7013888888888888
# 1.6622922134733158
# Right Aspect Ratio: 2.45
# Left Aspect Ratio: 2.6315789473684212
# 1.68
# 1.575609756097561
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.6842105263157894
# 1.702127659574468
# 1.642512077294686
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.55
# 1.8537590113285274
# 1.7997750281214848
# Right Aspect Ratio: 2.7777777777777777
# Left Aspect Ratio: 3.125
# 1.8036072144288577
# 1.7142857142857142
# Right Aspect Ratio: 2.7777777777777777
# Left Aspect Ratio: 3.1875
# 1.8050541516245486
# 1.6764705882352942
# Right Aspect Ratio: 2.5
# Left Aspect Ratio: 2.6842105263157894
# 1.7823639774859288
# 1.7647058823529411
# Right Aspect Ratio: 2.6315789473684212
# Left Aspect Ratio: 2.55
# 1.6259426847662142
# 1.6578947368421053
# Right Aspect Ratio: 2.227272727272727
# Left Aspect Ratio: 2.4285714285714284
# 1.6511127063890882
# 1.5499276410998553
# Right Aspect Ratio: 2.1739130434782608
# Left Aspect Ratio: 2.4285714285714284
# 1.7723880597014925
# 1.760306807286673
# Right Aspect Ratio: 2.6315789473684212
# Left Aspect Ratio: 2.8333333333333335
# 2.1492537313432836
# 1.985267034990792
# Right Aspect Ratio: 4.0
# Left Aspect Ratio: 4.454545454545454
# 1.6986518636003172
# 1.6612377850162867
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.55
# 1.7328185328185328
# 1.6527777777777777
# Right Aspect Ratio: 2.3181818181818183
# Left Aspect Ratio: 2.4285714285714284
# 1.738334858188472
# 1.7459459459459459
# Right Aspect Ratio: 2.6315789473684212
# Left Aspect Ratio: 2.6842105263157894
# 1.6881028938906752
# 1.650943396226415
# Right Aspect Ratio: 2.380952380952381
# Left Aspect Ratio: 2.380952380952381
# 1.7218543046357615
# 1.7210144927536233
# Right Aspect Ratio: 2.6
# Left Aspect Ratio: 2.6315789473684212
# 1.7369727047146402
# 1.7064846416382253
# Right Aspect Ratio: 2.380952380952381
# Left Aspect Ratio: 2.5
# 1.6351145038167938
# 1.6973058637083993
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.4285714285714284
# 1.6117729502452698
# 1.6272108843537414
# Right Aspect Ratio: 2.1739130434782608
# Left Aspect Ratio: 2.260869565217391
# 1.5770609318996416
# 1.638268156424581
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.217391304347826
# 1.7336485421591805
# 1.6846846846846846
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.3181818181818183
# 1.7099748533109806
# 1.6680032076984763
# Right Aspect Ratio: 2.55
# Left Aspect Ratio: 2.6
# 1.734412955465587
# 1.7
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.55
# 1.6284470246734397
# 1.6421052631578947
# Right Aspect Ratio: 2.3181818181818183
# Left Aspect Ratio: 2.4761904761904763
# 1.7647058823529411
# 1.6378233719892952
# Right Aspect Ratio: 2.55
# Left Aspect Ratio: 2.8333333333333335
# 1.585014409221902
# 1.6439560439560439
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.3181818181818183
# 1.574872169466764
# 1.6371249127704117
# Right Aspect Ratio: 2.227272727272727
# Left Aspect Ratio: 2.217391304347826
# 1.5499276410998553
# 1.6859504132231404
# Right Aspect Ratio: 2.4285714285714284
# Left Aspect Ratio: 2.3181818181818183
# 1.5978260869565217
# 1.5923190546528803
# Right Aspect Ratio: 2.3333333333333335
# Left Aspect Ratio: 2.227272727272727
# 1.5904572564612327
# 1.6115865701119156
# Right Aspect Ratio: 2.0833333333333335
# Left Aspect Ratio: 2.125
# 1.6291698991466252
# 1.6677471636952999
# Right Aspect Ratio: 2.380952380952381
# Left Aspect Ratio: 2.3333333333333335
# 1.543421052631579
# 1.649746192893401
# Right Aspect Ratio: 2.217391304347826
# Left Aspect Ratio: 2.08
# 1.6260162601626016
# 1.627266134880348
# Right Aspect Ratio: 2.272727272727273
# Left Aspect Ratio: 2.3181818181818183
# 1.6721311475409837
# 1.6284697508896797
# Right Aspect Ratio: 2.3181818181818183
# Left Aspect Ratio: 2.3636363636363638
# 1.6185784658691063
# 1.6370106761565837
# Right Aspect Ratio: 2.1739130434782608
# Left Aspect Ratio: 2.1739130434782608
# 1.610738255033557
# 1.619047619047619
# Right Aspect Ratio: 2.0833333333333335
# Left Aspect Ratio: 2.217391304347826
# 1.6212854181064271
# 1.6216949152542373
# Right Aspect Ratio: 2.217391304347826
# Left Aspect Ratio: 2.260869565217391
# 1.7723880597014925
# 1.7348551360842845
# Right Aspect Ratio: 2.6315789473684212
# Left Aspect Ratio: 2.736842105263158
# 1.7396449704142012
# 1.6253869969040247
# Right Aspect Ratio: 2.3333333333333335
# Left Aspect Ratio: 2.380952380952381
# 1.573187414500684
# 1.6106442577030813
# Right Aspect Ratio: 2.1739130434782608
# Left Aspect Ratio: 2.1739130434782608
# 1.6524590163934427
# 1.6411483253588517
# Right Aspect Ratio: 2.2857142857142856
# Left Aspect Ratio: 2.3333333333333335
# 1.75
# 1.7401812688821752
# Right Aspect Ratio: 2.7222222222222223
# Left Aspect Ratio: 2.6666666666666665
# 1.6246153846153846
# 1.6596774193548387
# Right Aspect Ratio: 2.1818181818181817
# Left Aspect Ratio: 2.3333333333333335
# 1.6143637782982045
# 1.665615141955836
# Right Aspect Ratio: 2.1363636363636362
# Left Aspect Ratio: 2.1818181818181817
# 1.674975074775673
# 1.8349954669084316
# Right Aspect Ratio: 2.1
# Left Aspect Ratio: 1.9130434782608696
# 1.8739088263821533
# 1.7316017316017316
# Right Aspect Ratio: 2.1904761904761907
# Left Aspect Ratio: 2.5
# 1.8482932996207333
# 1.6862745098039216
# Right Aspect Ratio: 2.5294117647058822
# Left Aspect Ratio: 2.5294117647058822

# %%
cap.release()
cv2.destroyAllWindows()
